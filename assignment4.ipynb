# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Housing.csv")
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Q1.  Write a program to find the average price of houses grouped by the number of bedrooms. 
# Display the result in descending order of average price.

data.groupby("bedrooms")["price"].mean(numeric_only=True).sort_values(ascending=False)
# Out:
# bedrooms
# 5    5.819800e+06
# 4    5.729758e+06
# 3    4.954598e+06
# 6    4.791500e+06
# 2    3.632022e+06
# 1    2.712500e+06
# Name: price, dtype: float64

# %%
#Q2. Create a program to calculate the total area of houses grouped by stories. 
# Display only the top 2 with the largest total area.
data.groupby("stories")["area"].sum(numeric_only=True).sort_values(ascending=False).head(2)
# Out:
# stories
# 1    1200790
# 2    1132153
# Name: area, dtype: int64

# %%
#Q3.  Determine the maximum price of houses based on whether they have hotwaterheating or not. 
# Also display the data of both rows. 

data.groupby("hotwaterheating")["price"].max(numeric_only=True)
# Out:
# hotwaterheating
# no     13300000
# yes     9681000
# Name: price, dtype: int64

# %%
#Q4.  Add a column named PricePerSqFt to calculate the price per square foot for each house. 
# Group the dataset by the number of floors and find the average PricePerSqFt for each group.

data["PricePerSqFt"] = data["price"] / data["area"]
data.groupby("floors")["PricePerSqFt"].mean(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 5
#       1 #Q4.  Add a column named PricePerSqFt to calculate the price per square foot for each house.
#       2 # Group the dataset by the number of floors and find the average PricePerSqFt for each group.
#       3
#       4 data["PricePerSqFt"] = data["price"] / data["area"]
# ----> 5 data.groupby("floors")["PricePerSqFt"].mean(numeric_only=True)
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\core\frame.py:10821, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10817
#   10818         if level is None and by is None:
#   10819             raise TypeError("You have to supply one of 'by' and 'level'")
#   10820
# > 10821         return DataFrameGroupBy(
#   10822             obj=self,
#   10823             keys=by,
#   10824             level=level,
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'floors'
