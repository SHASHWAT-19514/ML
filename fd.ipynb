# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('StudentsPerformance.csv')
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.value_counts('race/ethnicity')
data.head()
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race/ethnicity               1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 62.6 KB

# %%
data.rename(columns={'race/ethnicity':'groups'},inplace=True)
groups = data.groupby('groups') # This creates a groupby object named groups
print(groups) # This will print the groupby object, which is not very informative

# %%
for group,data in groups: # This way can be used to print that group data.. because it stores similiar as dictionary.
    print(group)
    print(data)
# Out:
# group A
#      gender   groups parental level of education         lunch  \
# 3      male  group A          associate's degree  free/reduced
# 13     male  group A                some college      standard
# 14   female  group A             master's degree      standard
# 25     male  group A             master's degree  free/reduced
# 46   female  group A          associate's degree      standard
# ..      ...      ...                         ...           ...
# 974  female  group A                some college      standard
# 983  female  group A                some college      standard
# 985    male  group A                 high school      standard
# 988  female  group A            some high school  free/reduced
# 994    male  group A                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# 3                      none          47             57             44
# ...

# %%
data.grouby('groups').sum(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data.grouby('groups').sum(numeric_only=True)
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'grouby'

# %%
groups.min(numeric_only=True)
# Out:
#          math score  reading score  writing score
# groups
# group A          28             23             19
# group B           8             24             15
# group C           0             17             10
# group D          26             31             32
# group E          30             26             22

# %%
groups.count() # This will count the number of non-null values in each group for each column.
# Out:
#          gender  parental level of education  lunch  test preparation course  \
# groups
# group A      89                           89     89                       89
# group B     190                          190    190                      190
# group C     319                          319    319                      319
# group D     262                          262    262                      262
# group E     140                          140    140                      140
#
#          math score  reading score  writing score
# groups
# group A          89             89             89
# group B         190            190            190
# group C         319            319            319
# group D         262            262            262
# group E         140            140            140

# %%
# Find that groups which scored highest total in math score
groups=data.groupby("groups")

data.groupby("groups")["math score"].sum(numeric_only=True).sort_value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 4
#       1 # Find that groups which scored highest total in math score
#       2 groups=data.groupby("groups")
#       3
# ----> 4 data.groupby("groups")["math score"].sum(numeric_only=True).sort_value()
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'sort_value'

# %%
#Find that group whcih scored min avg in writing
data.groupby("groups")["writing score"].mean(numeric_only=True).sort_values()
# Out:
# groups
# group E    71.407143
# Name: writing score, dtype: float64

# %%
#Find the  parental level of education which has hghest total in reading score
data.groupby("paretalelvelfoeducation")["reading score"].sum(numeric_only=True).sort_values()

# %%
#find the parental level of education which hashighestotalinreadinscore
data.groupby('parenta level of education').groups
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 #find the parental level of education which hashighestotalinreadinscore
# ----> 2 data.groupby("parenta level of education").groups
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\core\frame.py:10821, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10817
# ...

# %%
#size()
data.groupby('parental levle of education').size()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
#       1 #size()
# ----> 2 data.groupby('parental levle of education').size()
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\core\frame.py:10821, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10817
#   10818         if level is None and by is None:
# ...
