# %%
#! pip install pandas
! pip install seaborn
# Out:
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.3 MB 337.5 kB/s eta 0:00:23
#    -- ------------------------------------- 0.5/8.3 MB 337.5 kB/s eta 0:00:23
#    --- ------------------------------------ 0.8/8.3 MB 378.0 kB/s eta 0:00:20
#    --- ------------------------------------ 0.8/8.3 MB 378.0 kB/s eta 0:00:20
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
#using lists
data_sample = [
    [50,60,47],
    [70,73,75],
    [10,400,34],
    [60,5,20]
]
data1 = pd.DataFrame(data_sample, columns=['Python', 'C++', 'Java'])

data1
# Out:
#    Python  C++  Java
# 0      50   60    47
# 1      70   73    75
# 2      10  400    34
# 3      60    5    20

# %%
#using dicts
data_dict={
    'col1':[100,90,120,80,0,0],
    'col2':[80,70,100,50,0,0],
    'col3':[80,70,100,50,0,0],
    'col4':[80,70,100,50,0,0],

}
students= pd.DataFrame(data_dict)
#students.set_index('col1',inplace=True)
students

# %%
! pip3 install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
df1 = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
df3 = sns.load_dataset('tips')
d4 = sns.load_dataset('flights')
d5 = sns.load_dataset('diamonds')
d6 = sns.load_dataset('penguins')
d7 = sns.load_dataset('exercise')
d8 = sns.load_dataset('planets')
d9 = sns.load_dataset('mpg')
d10 = sns.load_dataset('car_crashes')
d11 = sns.load_dataset('dots')
d12 = sns.load_dataset('anscombe')
d13 = sns.load_dataset('attention')
d14 = sns.load_dataset('brain_networks')
d15 = sns.load_dataset('geyser')
d16 = sns.load_dataset('dots')
d17 = sns.load_dataset('anscombe')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(titanic.head())
print(titanic.shape)

# %%
#sammple given a dataframe, it will return a random row from the dataframe. It is useful when we want to check the data in the dataframe.
df2.sample(1)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 120         0       2  male  21.0      2      0  73.5        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# 120        True  NaN  Southampton    no  False

# %%
df2.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
df2.tail(1)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 890         0       3  male  32.0      0      0  7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 890        True  NaN  Queenstown    no   True

# %%
print(titanic.shape)

# %%
#datatype
df3 = sns.load_dataset('tips')
print(titanic['Age'].dtypes)
print()
print(titanic.dtypes)

# %%
#index
#print(titanic.index)
#columns
print(titanic.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
#Functions

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
titanic.describe() #to get the statistical summary of the dataset
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df3.isnull().sum() #to get the count of null values in each column of the dataset
df3.isnull() #to get the boolean values of null values in each column of the dataset
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
#duplicate values
titanic.duplicated().sum() #to get the count of duplicate values in the dataset
# Out:
# np.int64(107)

# %%
#drop duplicates
titanic.drop_duplicates(inplace=True) #to drop the duplicate values from the dataset

# %%
Create list,dict,pd.read-now("titanic.csv"),sns.loaddataset("")
Read methods:           attributes:
1. head()               1. shape
2. tail()               2. columns
3. sample()             3. dtypes
4. describe()           4. index
5. info()               5. memory_usage
6. isnull()             6. isna
7. duplicated()         7. drop_duplicates 
7. duplicated()

# %%
df3.head(1)
# Out:
#     Bill   tip     sex smoker  day    time  Number
# 0  16.99  1.01  Female     No  Sun  Dinner       2

# %%
df3.rename(columns={'total_bill':'Bill'}, inplace=True)
df3.rename(columns={'size':'Number'}, inplace=True)

# %%
df3.head()
# Out:
#     Bill   tip     sex smoker  day    time  Number
# 0  16.99  1.01  Female     No  Sun  Dinner       2
# 1  10.34  1.66    Male     No  Sun  Dinner       3
# 2  21.01  3.50    Male     No  Sun  Dinner       3
# 3  23.68  3.31    Male     No  Sun  Dinner       2
# 4  24.59  3.61  Female     No  Sun  Dinner       4

# %%
#titanic[['Name','Age']] used to select a specific column from the dataset

df3[['Bill','tip','smoker']] #to select specific columns from the dataset
# Out:
#       Bill   tip smoker
# 0    16.99  1.01     No
# 1    10.34  1.66     No
# 2    21.01  3.50     No
# 3    23.68  3.31     No
# 4    24.59  3.61     No
# ..     ...   ...    ...
# 239  29.03  5.92     No
# 240  27.18  2.00    Yes
# 241  22.67  2.00    Yes
# 242  17.82  1.75     No
# 243  18.78  3.00     No
#
# [244 rows x 3 columns]

# %%
#in loc end is included but in iloc end is not included
df3.iloc[5:36:2,3:]#to select specific rows and columns from the dataset using iloc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #in loc end is included but in iloc end is not included
# ----> 2 df3.iloc[5:36:2,3:] #to select specific rows and columns from the dataset using iloc
#
# NameError: name 'df3' is not defined

# %%
df3['tip'].astype('float 16')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df3['tip'].astype('float 16')
#
# NameError: name 'df3' is not defined

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
#change datatyppe of a column
titanic['survived'].astype('int32')
titanic['pclass'].astype('int32')
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int32

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
titanic['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
(titanic['day']=="Sun")&(titanic['sex']=='Female').value_counts()) #to filter the dataset based on specific conditions

# %%
#In titanic count the person those age are below 25
((titanic['sex']=='male')&(titanic['age']<25)).value_counts()
# Out:
# False    730
# True     161
# Name: count, dtype: int64

# %%
df=pd.DataFrame(data, index=labels)
df

# %%
data = {'creatures': ['Eagles', 'Eagles', 'Ducks', 'Herons', 'Herons', 
'Eagles', 'Ducks', 'Eagles', 'Herons', 'Herons', 'Eagles'],  
'weight': [2.0, 5, 3.0, np.nan, 7, 2.5, 6, np.nan, 9, 3, 2.0],  
'frequency': [1, 3, 2, 5, 2, 3, 1, 3, 4, 2, 1],  
'status': ['no', 'no', 'yes', np.nan, 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 
'no'],  
'height': [1.2, 2.5, 1.8, 3.0, 2.2, 1.9, 2.6, 1.4, 2.8, 2.3, 1.1],  
'region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 
'West', 'North', 'East', 'South'],  
'danger_level': ['low', 'medium', 'high', 'low', 'high', 'medium', 
'high', 'low', 'medium', 'high', 'low']} 
labels = ['x', 'y', 'z', 'w', 'v', 'u', 't', 's', 'r', 'q', 'p']
