#    -------------- ------------------------- 2.6/7.2 MB 136.5 kB/s eta 0:00:34
#    ----------------- ---------------------- 3.1/7.2 MB 165.5 kB/s eta 0:00:25
#    --------------------- ------------------ 3.9/7.2 MB 207.3 kB/s eta 0:00:16
#    ----------------------- ---------------- 4.2/7.2 MB 220.8 kB/s eta 0:00:14
#    --------------------------- ------------ 5.0/7.2 MB 260.8 kB/s eta 0:00:09
#    ------------------------------ --------- 5.5/7.2 MB 287.0 kB/s eta 0:00:06
#    ---------------------------------- ----- 6.3/7.2 MB 325.5 kB/s eta 0:00:03
#    ------------------------------------- -- 6.8/7.2 MB 350.2 kB/s eta 0:00:02
#    ------------------------------------- -- 6.8/7.2 MB 350.2 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
#    ---------------------------------------  7.1/7.2 MB 359.1 kB/s eta 0:00:01
# ...
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    --------------------------- ------------ 5.0/7.2 MB 157.0 kB/s eta 0:00:15
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ----------------------------- ---------- 5.2/7.2 MB 151.7 kB/s eta 0:00:14
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------ --------- 5.5/7.2 MB 141.2 kB/s eta 0:00:13
#    ------------------------------- -------- 5.8/7.2 MB 120.4 kB/s eta 0:00:13
#    ------------------------------- -------- 5.8/7.2 MB 120.4 kB/s eta 0:00:13
#    ------------------------------- -------- 5.8/7.2 MB 120.4 kB/s eta 0:00:13
#    ------------------------------- -------- 5.8/7.2 MB 120.4 kB/s eta 0:00:13
#    ------------------------------- -------- 5.8/7.2 MB 120.4 kB/s eta 0:00:13
#    ------------------------------- -------- 5.8/7.2 MB 120.4 kB/s eta 0:00:13
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    --------------------------------- ------ 6.0/7.2 MB 124.1 kB/s eta 0:00:10
#    ---------------------------------- ----- 6.3/7.2 MB 114.1 kB/s eta 0:00:09
#    ---------------------------------- ----- 6.3/7.2 MB 114.1 kB/s eta 0:00:09
#    ---------------------------------- ----- 6.3/7.2 MB 114.1 kB/s eta 0:00:09
#    ---------------------------------- ----- 6.3/7.2 MB 114.1 kB/s eta 0:00:09
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------ --- 6.6/7.2 MB 106.4 kB/s eta 0:00:07
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ------------------------------------- -- 6.8/7.2 MB 88.2 kB/s eta 0:00:05
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------  7.1/7.2 MB 91.3 kB/s eta 0:00:02
#    ---------------------------------------- 7.2/7.2 MB 89.7 kB/s  0:01:01
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [kiwisolver]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ---------------------------------------- 8/8 [seaborn]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.2.0 pyparsing-3.3.2 seaborn-0.13.2
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/matplotlib/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000026D55760F50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /packages/cd/8b/601e6566b957ca50e28725cb6c355c59c2c8609751efbecd980db44e0349/pillow-12.2.0-cp314-cp314-win_amd64.whl
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns

# %%
#HOW TO CREATE DATAFRAMES
#1. Create a dataframe USING "DICTIONARY"
data_dict = {
    'col1':['name1','name2','name3','name4','name5','name6'],
    'col2':[100,90,120,80,0,0],
    'col3':[80,70,100,50,0,0],
    'col4':[10,7,14,2,0,0]
            }

students = pd.DataFrame(data_dict)                  #create a dataframe from a dictionary
#students.set_index('col1',inplace=True)         #set the index to the column 'col1' (names of students)
students                                        #display the dataframe
# Out:
#     col1  col2  col3  col4
# 0  name1   100    80    10
# 1  name2    90    70     7
# 2  name3   120   100    14
# 3  name4    80    50     2
# 4  name5     0     0     0
# 5  name6     0     0     0

# %%
#HOW TO CREATE A DATAFRAME
#2. Create a dataframe USING "LISTS"
# using lists
data_sample =    [
    [50,60,47],
    [70,73,75],
    [10,400,34],
    [60,5,20]
                ]

data1 = pd.DataFrame(data_sample,columns=['python','C++','Java'])   #create a dataframe from a list of lists and assign column names
data1                                                               #display the dataframe
# Out:
#    python  C++  Java
# 0      50   60    47
# 1      70   73    75
# 2      10  400    34
# 3      60    5    20

# %%
#HOW TO CREATE A DATAFRAME
#3. Create a dataframe USING "CSV FILE"
#     Step      1.)      !pip install seaborn
#     Step      2.)      import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 7
#       3 #     Step      1.)      !pip install seaborn
#       4 #     Step      2.)      import seaborn as sns
#       5
#       6 # using read_csv
# ----> 7 titanic = pd.read_csv("Titanic Dataset.csv")
#       8 titanic
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\SHASHWAT SEN\Desktop\ML\.venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Titanic Dataset.csv'

# %%
! pip3 install seaborn      #installing seaborn library to load the "titanic" dataset
import seaborn as sns       #improting seaborn as alias sns
import pandas as pd         #importing pandas as alias pd
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '#installing': Expected package name at the start of dependency specifier
#     #installing
#     ^

# %%
#seaborn library has some inbuilt datasets which can be loaded using the load_dataset() function. The datasets are in the form of dataframes.
#The load_dataset() function takes the name of the dataset as an argument and returns a dataframe.
#The following are some of the datasets available in seaborn library:
#1. titanic
#2. iris and so on......

df1 = sns.load_dataset('titanic')
df2 = sns.load_dataset('iris')
df3 = sns.load_dataset('tips')
d4 = sns.load_dataset('flights')
d5 = sns.load_dataset('diamonds')
d6 = sns.load_dataset('penguins')
d7 = sns.load_dataset('exercise')
d8 = sns.load_dataset('planets')
d9 = sns.load_dataset('mpg')
d10 = sns.load_dataset('car_crashes')
d11 = sns.load_dataset('dots')
d12 = sns.load_dataset('anscombe')
d13 = sns.load_dataset('attention')
d14 = sns.load_dataset('brain_networks')
d15 = sns.load_dataset('geyser')
d16 = sns.load_dataset('dots')
d17 = sns.load_dataset('anscombe')
d18 = sns.load_dataset('attention')
d19 = sns.load_dataset('brain_networks')
d20 = sns.load_dataset('geyser')

# %%
# using read_csv
titanic = pd.read_csv("Titanic Dataset.csv") #read the csv file and create a dataframe
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
#DATAFRAME ATTRIBUTES AND METHODS
            #1. shape       #1. info           
            #2. dtypes      #2. describe
            #3. index       #3. head and tail
            #4. columns
            #5. values

# %%
print(titanic.head())
print(titanic.shape)

# %%
#sammple given a dataframe, it will return a random row from the dataframe. It is useful when we want to check the data in the dataframe.
df2.sample(1)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 120         0       2  male  21.0      2      0  73.5        S  Second  man
#
#      adult_male deck  embark_town alive  alone
# 120        True  NaN  Southampton    no  False

# %%
df2.head(1)
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  22.0      1      0  7.25        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False

# %%
df2.tail(1)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 890         0       3  male  32.0      0      0  7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 890        True  NaN  Queenstown    no   True

# %%
print(titanic.shape)

# %%
#datatype
df3 = sns.load_dataset('tips')
print(titanic['Age'].dtypes)
print()
print(titanic.dtypes)

# %%
#index
#print(titanic.index)
#columns
print(titanic.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='str')

# %%
#Functions

# %%
titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
titanic.describe() #to get the statistical summary of the dataset
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df3.isnull().sum() #to get the count of null values in each column of the dataset
df3.isnull() #to get the boolean values of null values in each column of the dataset
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
#duplicate values
titanic.duplicated().sum() #to get the count of duplicate values in the dataset
# Out:
# np.int64(107)

# %%
#drop duplicates
titanic.drop_duplicates(inplace=True) #to drop the duplicate values from the dataset

# %%
df3.head(1)
# Out:
#     Bill   tip     sex smoker  day    time  Number
# 0  16.99  1.01  Female     No  Sun  Dinner       2

# %%
df3.rename(columns={'total_bill':'Bill'}, inplace=True)
df3.rename(columns={'size':'Number'}, inplace=True)

# %%
df3.head()
# Out:
#     Bill   tip     sex smoker  day    time  Number
# 0  16.99  1.01  Female     No  Sun  Dinner       2
# 1  10.34  1.66    Male     No  Sun  Dinner       3
# 2  21.01  3.50    Male     No  Sun  Dinner       3
# 3  23.68  3.31    Male     No  Sun  Dinner       2
# 4  24.59  3.61  Female     No  Sun  Dinner       4

# %%
#titanic[['Name','Age']] used to select a specific column from the dataset

df3[['Bill','tip','smoker']] #to select specific columns from the dataset
# Out:
#       Bill   tip smoker
# 0    16.99  1.01     No
# 1    10.34  1.66     No
# 2    21.01  3.50     No
# 3    23.68  3.31     No
# 4    24.59  3.61     No
# ..     ...   ...    ...
# 239  29.03  5.92     No
# 240  27.18  2.00    Yes
# 241  22.67  2.00    Yes
# 242  17.82  1.75     No
# 243  18.78  3.00     No
#
# [244 rows x 3 columns]

# %%
#in loc end is included but in iloc end is not included
df3.iloc[5:36:2,3:]#to select specific rows and columns from the dataset using iloc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 #in loc end is included but in iloc end is not included
# ----> 2 df3.iloc[5:36:2,3:] #to select specific rows and columns from the dataset using iloc
#
# NameError: name 'df3' is not defined

# %%
df3['tip'].astype('float 16')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df3['tip'].astype('float 16')
#
# NameError: name 'df3' is not defined

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
#change datatyppe of a column
titanic['survived'].astype('int32')
titanic['pclass'].astype('int32')
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: pclass, Length: 891, dtype: int32

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    str
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    str
#  8   class        891 non-null    category
#  9   who          891 non-null    str
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    str
#  13  alive        891 non-null    str
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), str(5)
# memory usage: 80.7 KB

# %%
titanic['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
(titanic['day']=="Sun")&(titanic['sex']=='Female').value_counts()) #to filter the dataset based on specific conditions

# %%
#In titanic count the person those age are below 25
((titanic['sex']=='male')&(titanic['age']<25)).value_counts()
# Out:
# False    730
# True     161
# Name: count, dtype: int64

# %%
df=pd.DataFrame(data, index=labels)
df

# %%
data = {'creatures': ['Eagles', 'Eagles', 'Ducks', 'Herons', 'Herons', 
'Eagles', 'Ducks', 'Eagles', 'Herons', 'Herons', 'Eagles'],  
'weight': [2.0, 5, 3.0, np.nan, 7, 2.5, 6, np.nan, 9, 3, 2.0],  
'frequency': [1, 3, 2, 5, 2, 3, 1, 3, 4, 2, 1],  
'status': ['no', 'no', 'yes', np.nan, 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 
'no'],  
'height': [1.2, 2.5, 1.8, 3.0, 2.2, 1.9, 2.6, 1.4, 2.8, 2.3, 1.1],  
'region': ['North', 'South', 'East', 'West', 'North', 'South', 'East', 
'West', 'North', 'East', 'South'],  
'danger_level': ['low', 'medium', 'high', 'low', 'high', 'medium', 
'high', 'low', 'medium', 'high', 'low']} 
labels = ['x', 'y', 'z', 'w', 'v', 'u', 't', 's', 'r', 'q', 'p']
